# %%
import os
import pandas as pd

# %%
MOVEMENTS = (
    "elbflex",
    "shoabd",
    "shoext",
    "shoflex",
    "hipabd",
    "hipext",
    "hipflex",
    "kneeflex",
)

# %%
movement = "elbflex"
path = f"./gen/{movement}/model/"
filename = "dl200_right_upper_elbflex_024.csv"
trial_df = pd.read_csv(f"{path}/{filename}", index_col=0) # rows are frames, columns are joint names.
num_trial_frames = trial_df.shape[0]
joint_name = [col for col in trial_df.columns if movement[:3] in col][0]
num_good_trial_frames = trial_df[joint_name].dropna().shape[0]
dropped_frames = ((num_trial_frames - num_good_trial_frames) / num_trial_frames)
# Out:
# 0.7976878612716763

# %%
# Get path to participant & movement model generated CSVs.
# 
# trial_info dictionary:
# {
#   "dl200": {
#              "left_upper_elbflex": {"total_frames": 346, "good_frames": 70, "drop_percent": 0.80},
#              "left_upper_shoabd":  {...},
#              ...
#            },
#   "dl201": { ... },
#   ...
# }

trial_info = dict()
for movement in MOVEMENTS:
    path = f"./gen/{movement}/model/"
    for filename in os.listdir(path):
        if filename.endswith('.csv'):
            participant = filename.split('_')[0] # e.g. dl200
            group_and_movement = '_'.join(filename.split('_')[1:4]) # e.g. right_upper_elbflex
            trial_num = filename.strip('.csv').split('_')[-1]
            
            trial_df = pd.read_csv(f"{path}/{filename}", index_col=0)
            joint_name = [col for col in trial_df.columns if movement[:3] in col][0]
            
            total_frames = trial_df.shape[0]
            good_frames = trial_df[joint_name].dropna().shape[0]
            drop_percent = round((total_frames - good_frames) / total_frames, 2)
            
            trial_info.setdefault(participant, {})
            trial_info[participant].setdefault(group_and_movement, {})
            
            trial_info[participant][group_and_movement][trial_num] = {
                "total_frames": total_frames,
                "good_frames": good_frames,
                "drop_percent": drop_percent
            }
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-8767de2816eb> in <module>
#      26             total_frames = trial_df.shape[0]
#      27             good_frames = trial_df[joint_name].dropna().shape[0]
# ---> 28             drop_percent = ((total_frames - good_frames) / total_frames).round(2)
#      29
#      30             trial_info.setdefault(participant, {})
#
# AttributeError: 'float' object has no attribute 'round'

# %%
trial_info
# Out:
# {'dl200': {'right_upper_elbflex': {'024': {'total_frames': 346,
#     'good_frames': 70,
#     'drop_percent': 0.7976878612716763},
#    '027': {'total_frames': 341,
#     'good_frames': 66,
#     'drop_percent': 0.8064516129032258},
#    '007': {'total_frames': 343,
#     'good_frames': 117,
#     'drop_percent': 0.6588921282798834},
#    '026': {'total_frames': 346,
#     'good_frames': 73,
#     'drop_percent': 0.7890173410404624},
#    '029': {'total_frames': 325,
#     'good_frames': 67,
#     'drop_percent': 0.7938461538461539},
#    '031': {'total_frames': 319,
#     'good_frames': 112,
#     'drop_percent': 0.6489028213166145},
#    '005': {'total_frames': 332,
#     'good_frames': 113,
#     'drop_percent': 0.6596385542168675},
#    '023': {'total_frames': 314,
#     'good_frames': 79,
#     'drop_percent': 0.7484076433121019},
#    '006': {'total_frames': 320, 'good_frames': 112, 'drop_percent': 0.65},
#    '009': {'total_frames': 325,
#     'good_frames': 109,
#     'drop_percent': 0.6646153846153846},
#    '021': {'total_frames': 295,
#     'good_frames': 69,
#     'drop_percent': 0.7661016949152543},
#    '010': {'total_frames': 323,
#     'good_frames': 83,
#     'drop_percent': 0.7430340557275542},
#    '022': {'total_frames': 305,
#     'good_frames': 68,
#     'drop_percent': 0.7770491803278688},
#    '003': {'total_frames': 310, 'good_frames': 124, 'drop_percent': 0.6},
#    '008': {'total_frames': 309,
#     'good_frames': 91,
#     'drop_percent': 0.7055016181229773},
#    '025': {'total_frames': 317,
#     'good_frames': 65,
#     'drop_percent': 0.7949526813880127},
#    '001': {'total_frames': 276,
#     'good_frames': 149,
#     'drop_percent': 0.4601449275362319},
#    '030': {'total_frames': 327,
#     'good_frames': 70,
#     'drop_percent': 0.7859327217125383},
#    '004': {'total_frames': 304, 'good_frames': 114, 'drop_percent': 0.625},
#    '028': {'total_frames': 328,
#     'good_frames': 74,
#     'drop_percent': 0.774390243902439},
#    '002': {'total_frames': 280, 'good_frames': 133, 'drop_percent': 0.525}},
#   'left_upper_elbflex': {'006': {'total_frames': 325,
#     'good_frames': 313,
#     'drop_percent': 0.036923076923076927},
#    '003': {'total_frames': 312,
#     'good_frames': 310,
#     'drop_percent': 0.00641025641025641},
#    '001': {'total_frames': 296,
#     'good_frames': 287,
#     'drop_percent': 0.030405405405405407},
#    '010': {'total_frames': 335,
#     'good_frames': 333,
#     'drop_percent': 0.005970149253731343},
#    '028': {'total_frames': 321,
#     'good_frames': 136,
#     'drop_percent': 0.5763239875389408},
#    '026': {'total_frames': 308,
#     'good_frames': 95,
#     'drop_percent': 0.6915584415584416},
#    '004': {'total_frames': 319,
#     'good_frames': 315,
#     'drop_percent': 0.012539184952978056},
#    '025': {'total_frames': 327,
#     'good_frames': 110,
#     'drop_percent': 0.6636085626911316},
#    '020': {'total_frames': 300, 'good_frames': 126, 'drop_percent': 0.58},
#    '007': {'total_frames': 373,
#     'good_frames': 370,
#     'drop_percent': 0.00804289544235925},
#    '030': {'total_frames': 300, 'good_frames': 108, 'drop_percent': 0.64},
#    '005': {'total_frames': 340,
#     'good_frames': 327,
#     'drop_percent': 0.03823529411764706},
#    '024': {'total_frames': 308,
#     'good_frames': 102,
#     'drop_percent': 0.6688311688311688},
#    '027': {'total_frames': 322,
#     'good_frames': 78,
#     'drop_percent': 0.7577639751552795},
#    '002': {'total_frames': 308,
#     'good_frames': 304,
#     'drop_percent': 0.012987012987012988},
#    '009': {'total_frames': 356,
#     'good_frames': 353,
#     'drop_percent': 0.008426966292134831},
#    '022': {'total_frames': 291,
#     'good_frames': 127,
#     'drop_percent': 0.563573883161512},
#    '023': {'total_frames': 291,
#     'good_frames': 121,
#     'drop_percent': 0.584192439862543},
#    '021': {'total_frames': 313,
#     'good_frames': 131,
#     'drop_percent': 0.5814696485623003},
#    '029': {'total_frames': 344,
#     'good_frames': 96,
#     'drop_percent': 0.7209302325581395},
#    '008': {'total_frames': 334,
#     'good_frames': 330,
#     'drop_percent': 0.011976047904191617}},
#   'right_upper_shoabd': {'023': {'total_frames': 327,
#     'good_frames': 289,
#     'drop_percent': 0.1162079510703364},
#    '010': {'total_frames': 297,
#     'good_frames': 70,
#     'drop_percent': 0.7643097643097643},
#    '024': {'total_frames': 321,
#     'good_frames': 235,
#     'drop_percent': 0.26791277258566976},
#    '027': {'total_frames': 347,
#     'good_frames': 261,
#     'drop_percent': 0.2478386167146974},
#    '025': {'total_frames': 319,
#     'good_frames': 244,
#     'drop_percent': 0.23510971786833856},
#    '009': {'total_frames': 319,
#     'good_frames': 61,
#     'drop_percent': 0.8087774294670846},
#    '005': {'total_frames': 304,
#     'good_frames': 75,
#     'drop_percent': 0.7532894736842105},
#    '006': {'total_frames': 299,
#     'good_frames': 81,
#     'drop_percent': 0.7290969899665551},
#    '030': {'total_frames': 340,
#     'good_frames': 252,
#     'drop_percent': 0.25882352941176473},
#    '029': {'total_frames': 338,
#     'good_frames': 252,
#     'drop_percent': 0.25443786982248523},
#    '008': {'total_frames': 296,
#     'good_frames': 63,
#     'drop_percent': 0.7871621621621622},
#    '028': {'total_frames': 332,
#     'good_frames': 267,
#     'drop_percent': 0.19578313253012047},
#    '002': {'total_frames': 329,
#     'good_frames': 264,
#     'drop_percent': 0.19756838905775076},
#    '003': {'total_frames': 292,
#     'good_frames': 187,
#     'drop_percent': 0.3595890410958904},
#    '001': {'total_frames': 336,
#     'good_frames': 215,
#     'drop_percent': 0.3601190476190476},
#    '022': {'total_frames': 373,
#     'good_frames': 285,
#     'drop_percent': 0.2359249329758713},
#    '004': {'total_frames': 316,
#     'good_frames': 76,
#     'drop_percent': 0.759493670886076},
#    '026': {'total_frames': 346,
#     'good_frames': 254,
#     'drop_percent': 0.2658959537572254},
#    '007': {'total_frames': 303,
#     'good_frames': 62,
#     'drop_percent': 0.7953795379537953},
#    '021': {'total_frames': 316,
#     'good_frames': 202,
#     'drop_percent': 0.36075949367088606}},
#   'left_upper_shoabd': {'024': {'total_frames': 319,
#     'good_frames': 278,
#     'drop_percent': 0.12852664576802508},
#    '025': {'total_frames': 355,
#     'good_frames': 290,
#     'drop_percent': 0.18309859154929578},
#    '005': {'total_frames': 324,
#     'good_frames': 159,
#     'drop_percent': 0.5092592592592593},
#    '003': {'total_frames': 339,
#     'good_frames': 182,
#     'drop_percent': 0.4631268436578171},
#    '011': {'total_frames': 308,
#     'good_frames': 195,
#     'drop_percent': 0.36688311688311687},
#    '027': {'total_frames': 300,
#     'good_frames': 256,
#     'drop_percent': 0.14666666666666667},
#    '031': {'total_frames': 356,
#     'good_frames': 292,
#     'drop_percent': 0.1797752808988764},
#    '032': {'total_frames': 314,
#     'good_frames': 255,
#     'drop_percent': 0.18789808917197454},
#    '004': {'total_frames': 325,
#     'good_frames': 147,
#     'drop_percent': 0.5476923076923077},
#    '033': {'total_frames': 344,
#     'good_frames': 288,
#     'drop_percent': 0.16279069767441862},
#    '008': {'total_frames': 312,
#     'good_frames': 218,
#     'drop_percent': 0.30128205128205127},
#    '026': {'total_frames': 326,
#     'good_frames': 267,
#     'drop_percent': 0.18098159509202455},
#    '010': {'total_frames': 354,
#     'good_frames': 208,
#     'drop_percent': 0.4124293785310734},
#    '009': {'total_frames': 319,
#     'good_frames': 195,
#     'drop_percent': 0.3887147335423197},
#    '006': {'total_frames': 314,
#     'good_frames': 139,
#     'drop_percent': 0.5573248407643312},
#    '021': {'total_frames': 336,
#     'good_frames': 261,
#     'drop_percent': 0.22321428571428573},
#    '029': {'total_frames': 344,
#     'good_frames': 293,
#     'drop_percent': 0.14825581395348839},
#    '007': {'total_frames': 302,
#     'good_frames': 177,
#     'drop_percent': 0.4139072847682119},
#    '023': {'total_frames': 321,
#     'good_frames': 288,
#     'drop_percent': 0.102803738317757},
#    '001': {'total_frames': 321,
#     'good_frames': 245,
#     'drop_percent': 0.2367601246105919},
#    '028': {'total_frames': 319,
#     'good_frames': 243,
#     'drop_percent': 0.23824451410658307},
#    '022': {'total_frames': 318,
#     'good_frames': 267,
#     'drop_percent': 0.16037735849056603},
#    '012': {'total_frames': 336,
#     'good_frames': 148,
#     'drop_percent': 0.5595238095238095},
#    '020': {'total_frames': 328,
#     'good_frames': 184,
#     'drop_percent': 0.43902439024390244},
#    '002': {'total_frames': 335,
#     'good_frames': 193,
#     'drop_percent': 0.42388059701492536},
#    '030': {'total_frames': 336,
#     'good_frames': 282,
#     'drop_percent': 0.16071428571428573}},
#   'right_upper_shoext': {'010': {'total_frames': 324,
#     'good_frames': 109,
#     'drop_percent': 0.6635802469135802},
#    '003': {'total_frames': 362,
#     'good_frames': 145,
#     'drop_percent': 0.5994475138121547},
#    '002': {'total_frames': 391,
#     'good_frames': 144,
#     'drop_percent': 0.6317135549872123},
#    '009': {'total_frames': 303,
#     'good_frames': 83,
#     'drop_percent': 0.7260726072607261},
#    '024': {'total_frames': 341,
#     'good_frames': 44,
#     'drop_percent': 0.8709677419354839},
#    '027': {'total_frames': 348,
#     'good_frames': 28,
#     'drop_percent': 0.9195402298850575},
#    '030': {'total_frames': 368,
#     'good_frames': 13,
#     'drop_percent': 0.9646739130434783},
#    '001': {'total_frames': 272,
#     'good_frames': 91,
#     'drop_percent': 0.6654411764705882},
#    '025': {'total_frames': 346,
#     'good_frames': 75,
#     'drop_percent': 0.7832369942196532},
#    '023': {'total_frames': 342,
#     'good_frames': 24,
#     'drop_percent': 0.9298245614035088},
#    '028': {'total_frames': 349,
#     'good_frames': 95,
#     'drop_percent': 0.7277936962750716},
#    '029': {'total_frames': 356,
#     'good_frames': 55,
#     'drop_percent': 0.8455056179775281},
#    '007': {'total_frames': 363,
#     'good_frames': 99,
#     'drop_percent': 0.7272727272727273},
#    '021': {'total_frames': 294,
#     'good_frames': 20,
#     'drop_percent': 0.9319727891156463},
#    '006': {'total_frames': 344,
#     'good_frames': 100,
#     'drop_percent': 0.7093023255813954},
#    '022': {'total_frames': 309,
#     'good_frames': 10,
#     'drop_percent': 0.9676375404530745},
#    '026': {'total_frames': 367,
#     'good_frames': 48,
#     'drop_percent': 0.8692098092643051},
#    '005': {'total_frames': 349,
#     'good_frames': 118,
#     'drop_percent': 0.66189111747851},
#    '008': {'total_frames': 371,
#     'good_frames': 102,
#     'drop_percent': 0.7250673854447439},
#    '004': {'total_frames': 296,
#     'good_frames': 66,
#     'drop_percent': 0.777027027027027},
#    '031': {'total_frames': 317,
#     'good_frames': 70,
#     'drop_percent': 0.7791798107255521}},
#   'left_upper_shoext': {'001': {'total_frames': 309,
#     'good_frames': 284,
#     'drop_percent': 0.08090614886731391},
#    '002': {'total_frames': 277,
#     'good_frames': 259,
#     'drop_percent': 0.06498194945848375},
#    '004': {'total_frames': 300, 'good_frames': 261, 'drop_percent': 0.13},
#    '007': {'total_frames': 332,
#     'good_frames': 307,
#     'drop_percent': 0.07530120481927711},
#    '010': {'total_frames': 327,
#     'good_frames': 270,
#     'drop_percent': 0.1743119266055046},
#    '027': {'total_frames': 304,
#     'good_frames': 135,
#     'drop_percent': 0.555921052631579},
#    '006': {'total_frames': 331,
#     'good_frames': 307,
#     'drop_percent': 0.07250755287009064},
#    '030': {'total_frames': 304, 'good_frames': 152, 'drop_percent': 0.5},
#    '020': {'total_frames': 256, 'good_frames': 182, 'drop_percent': 0.2890625},
#    '009': {'total_frames': 275,
#     'good_frames': 250,
#     'drop_percent': 0.09090909090909091},
#    '023': {'total_frames': 295,
#     'good_frames': 132,
#     'drop_percent': 0.5525423728813559},
#    '024': {'total_frames': 316,
#     'good_frames': 143,
#     'drop_percent': 0.5474683544303798},
#    '022': {'total_frames': 294,
#     'good_frames': 153,
#     'drop_percent': 0.47959183673469385},
#    '029': {'total_frames': 360,
#     'good_frames': 169,
#     'drop_percent': 0.5305555555555556},
#    '031': {'total_frames': 453,
#     'good_frames': 187,
#     'drop_percent': 0.58719646799117},
#    '003': {'total_frames': 308,
#     'good_frames': 275,
#     'drop_percent': 0.10714285714285714},
#    '026': {'total_frames': 344,
#     'good_frames': 166,
#     'drop_percent': 0.5174418604651163},
#    '028': {'total_frames': 311,
#     'good_frames': 144,
#     'drop_percent': 0.5369774919614148},
#    '005': {'total_frames': 294,
#     'good_frames': 243,
#     'drop_percent': 0.17346938775510204},
#    '021': {'total_frames': 287,
#     'good_frames': 147,
#     'drop_percent': 0.4878048780487805},
#    '025': {'total_frames': 294,
#     'good_frames': 187,
#     'drop_percent': 0.36394557823129253},
#    '008': {'total_frames': 357,
#     'good_frames': 327,
#     'drop_percent': 0.08403361344537816}},
#   'left_upper_shoflex': {'008': {'total_frames': 317,
#     'good_frames': 79,
#     'drop_percent': 0.750788643533123},
#    '025': {'total_frames': 365,
#     'good_frames': 276,
#     'drop_percent': 0.24383561643835616},
#    '023': {'total_frames': 371,
#     'good_frames': 272,
#     'drop_percent': 0.2668463611859838},
#    '005': {'total_frames': 350,
#     'good_frames': 172,
#     'drop_percent': 0.5085714285714286},
#    '026': {'total_frames': 323,
#     'good_frames': 236,
#     'drop_percent': 0.2693498452012384},
#    '028': {'total_frames': 377,
#     'good_frames': 265,
#     'drop_percent': 0.29708222811671087},
#    '009': {'total_frames': 369,
#     'good_frames': 132,
#     'drop_percent': 0.6422764227642277},
#    '021': {'total_frames': 340,
#     'good_frames': 213,
#     'drop_percent': 0.3735294117647059},
#    '006': {'total_frames': 360,
#     'good_frames': 229,
#     'drop_percent': 0.3638888888888889},
#    '002': {'total_frames': 360,
#     'good_frames': 264,
#     'drop_percent': 0.26666666666666666},
#    '003': {'total_frames': 382,
#     'good_frames': 249,
#     'drop_percent': 0.3481675392670157},
#    '001': {'total_frames': 344,
#     'good_frames': 252,
#     'drop_percent': 0.26744186046511625},
#    '004': {'total_frames': 335,
#     'good_frames': 210,
#     'drop_percent': 0.373134328358209},
#    '027': {'total_frames': 321,
#     'good_frames': 226,
#     'drop_percent': 0.29595015576323985},
#    '010': {'total_frames': 351,
#     'good_frames': 206,
#     'drop_percent': 0.4131054131054131},
#    '022': {'total_frames': 386,
#     'good_frames': 242,
#     'drop_percent': 0.37305699481865284},
#    '024': {'total_frames': 341,
#     'good_frames': 260,
#     'drop_percent': 0.2375366568914956},
#    '020': {'total_frames': 361,
#     'good_frames': 147,
#     'drop_percent': 0.592797783933518},
#    '030': {'total_frames': 396,
#     'good_frames': 323,
#     'drop_percent': 0.18434343434343434},
#    '007': {'total_frames': 373,
#     'good_frames': 106,
#     'drop_percent': 0.7158176943699732},
#    '029': {'total_frames': 366,
#     'good_frames': 293,
#     'drop_percent': 0.1994535519125683}},
#   'right_upper_shoflex': {'030': {'total_frames': 357,
#     'good_frames': 65,
#     'drop_percent': 0.8179271708683473},
#    '021': {'total_frames': 470,
#     'good_frames': 109,
#     'drop_percent': 0.7680851063829788},
#    '003': {'total_frames': 377,
#     'good_frames': 80,
#     'drop_percent': 0.7877984084880637},
#    '026': {'total_frames': 391,
#     'good_frames': 61,
#     'drop_percent': 0.8439897698209718},
#    '029': {'total_frames': 333,
#     'good_frames': 75,
#     'drop_percent': 0.7747747747747747},
#    '022': {'total_frames': 351,
#     'good_frames': 64,
#     'drop_percent': 0.8176638176638177},
#    '006': {'total_frames': 335,
#     'good_frames': 99,
#     'drop_percent': 0.7044776119402985},
#    '001': {'total_frames': 314,
#     'good_frames': 72,
#     'drop_percent': 0.7707006369426752},
#    '027': {'total_frames': 382,
#     'good_frames': 72,
#     'drop_percent': 0.8115183246073299},
#    '025': {'total_frames': 364,
#     'good_frames': 43,
#     'drop_percent': 0.8818681318681318},
#    '023': {'total_frames': 336,
#     'good_frames': 62,
#     'drop_percent': 0.8154761904761905},
#    '007': {'total_frames': 331,
#     'good_frames': 96,
#     'drop_percent': 0.7099697885196374},
#    '024': {'total_frames': 370,
#     'good_frames': 60,
#     'drop_percent': 0.8378378378378378},
#    '004': {'total_frames': 290,
#     'good_frames': 67,
#     'drop_percent': 0.7689655172413793},
#    '002': {'total_frames': 301,
#     'good_frames': 107,
#     'drop_percent': 0.6445182724252492},
#    '009': {'total_frames': 358,
#     'good_frames': 98,
#     'drop_percent': 0.7262569832402235},
#    '028': {'total_frames': 370,
#     'good_frames': 60,
#     'drop_percent': 0.8378378378378378},
#    '008': {'total_frames': 359,
#     'good_frames': 87,
#     'drop_percent': 0.7576601671309192},
#    '010': {'total_frames': 340,
#     'good_frames': 89,
#     'drop_percent': 0.7382352941176471},
#    '005': {'total_frames': 332,
#     'good_frames': 67,
#     'drop_percent': 0.7981927710843374}}},
#  'dl201': {'right_upper_elbflex': {'035': {'total_frames': 344,
#     'good_frames': 303,
#     'drop_percent': 0.11918604651162791},
#    '001': {'total_frames': 352,
#     'good_frames': 183,
#     'drop_percent': 0.48011363636363635},
#    '003': {'total_frames': 325, 'good_frames': 299, 'drop_percent': 0.08},
#    '007': {'total_frames': 396,
#     'good_frames': 380,
#     'drop_percent': 0.04040404040404041},
#    '020': {'total_frames': 286,
#     'good_frames': 206,
#     'drop_percent': 0.27972027972027974},
#    '027': {'total_frames': 371,
#     'good_frames': 350,
#     'drop_percent': 0.05660377358490566},
#    '021': {'total_frames': 405,
#     'good_frames': 274,
#     'drop_percent': 0.3234567901234568},
#    '004': {'total_frames': 322,
#     'good_frames': 259,
#     'drop_percent': 0.1956521739130435},
#    '030': {'total_frames': 348,
#     'good_frames': 242,
#     'drop_percent': 0.3045977011494253},
#    '029': {'total_frames': 357,
#     'good_frames': 197,
#     'drop_percent': 0.4481792717086835},
#    '033': {'total_frames': 382,
#     'good_frames': 345,
#     'drop_percent': 0.0968586387434555},
#    '034': {'total_frames': 366,
#     'good_frames': 274,
#     'drop_percent': 0.25136612021857924},
#    '008': {'total_frames': 448,
#     'good_frames': 270,
#     'drop_percent': 0.39732142857142855},
#    '028': {'total_frames': 370,
#     'good_frames': 363,
#     'drop_percent': 0.01891891891891892},
#    '024': {'total_frames': 337,
#     'good_frames': 273,
#     'drop_percent': 0.18991097922848665},
#    '031': {'total_frames': 351,
#     'good_frames': 276,
#     'drop_percent': 0.21367521367521367},
#    '005': {'total_frames': 360,
#     'good_frames': 267,
#     'drop_percent': 0.25833333333333336},
#    '023': {'total_frames': 300,
#     'good_frames': 176,
#     'drop_percent': 0.41333333333333333},
#    '022': {'total_frames': 358,
#     'good_frames': 287,
#     'drop_percent': 0.19832402234636873},
#    '009': {'total_frames': 357,
#     'good_frames': 239,
#     'drop_percent': 0.33053221288515405},
#    '011': {'total_frames': 372,
#     'good_frames': 339,
#     'drop_percent': 0.08870967741935484},
#    '010': {'total_frames': 361,
#     'good_frames': 336,
#     'drop_percent': 0.06925207756232687},
#    '006': {'total_frames': 318,
#     'good_frames': 284,
#     'drop_percent': 0.1069182389937107},
#    '032': {'total_frames': 428,
#     'good_frames': 379,
#     'drop_percent': 0.11448598130841121}},
#   'left_upper_elbflex': {'031': {'total_frames': 327,
#     'good_frames': 197,
#     'drop_percent': 0.39755351681957185},
#    '006': {'total_frames': 372,
#     'good_frames': 342,
#     'drop_percent': 0.08064516129032258},
#    '001': {'total_frames': 282,
#     'good_frames': 249,
#     'drop_percent': 0.11702127659574468},
#    '034': {'total_frames': 306,
#     'good_frames': 273,
#     'drop_percent': 0.10784313725490197},
#    '009': {'total_frames': 328,
#     'good_frames': 223,
#     'drop_percent': 0.3201219512195122},
#    '025': {'total_frames': 302,
#     'good_frames': 93,
#     'drop_percent': 0.6920529801324503},
#    '021': {'total_frames': 327,
#     'good_frames': 301,
#     'drop_percent': 0.07951070336391437},
#    '005': {'total_frames': 361,
#     'good_frames': 334,
#     'drop_percent': 0.07479224376731301},
#    '029': {'total_frames': 321,
#     'good_frames': 242,
#     'drop_percent': 0.24610591900311526},
#    '022': {'total_frames': 246,
#     'good_frames': 193,
#     'drop_percent': 0.21544715447154472},
#    '030': {'total_frames': 291,
#     'good_frames': 248,
#     'drop_percent': 0.14776632302405499},
#    '007': {'total_frames': 405,
#     'good_frames': 379,
#     'drop_percent': 0.06419753086419754},
#    '011': {'total_frames': 359,
#     'good_frames': 301,
#     'drop_percent': 0.1615598885793872},
#    '028': {'total_frames': 293,
#     'good_frames': 206,
#     'drop_percent': 0.29692832764505117},
#    '027': {'total_frames': 281,
#     'good_frames': 250,
#     'drop_percent': 0.1103202846975089},
#    '024': {'total_frames': 266,
#     'good_frames': 106,
#     'drop_percent': 0.6015037593984962},
#    '026': {'total_frames': 287,
#     'good_frames': 244,
#     'drop_percent': 0.14982578397212543},
#    '003': {'total_frames': 365,
#     'good_frames': 343,
#     'drop_percent': 0.06027397260273973},
#    '020': {'total_frames': 315,
#     'good_frames': 282,
#     'drop_percent': 0.10476190476190476},
#    '012': {'total_frames': 324,
#     'good_frames': 253,
#     'drop_percent': 0.2191358024691358},
#    '032': {'total_frames': 281,
#     'good_frames': 216,
#     'drop_percent': 0.2313167259786477},
#    '010': {'total_frames': 373,
#     'good_frames': 281,
#     'drop_percent': 0.24664879356568364},
#    '023': {'total_frames': 300,
#     'good_frames': 212,
#     'drop_percent': 0.29333333333333333},
#    '004': {'total_frames': 327,
#     'good_frames': 304,
#     'drop_percent': 0.07033639143730887},
#    '033': {'total_frames': 277,
#     'good_frames': 190,
#     'drop_percent': 0.3140794223826715},
#    '002': {'total_frames': 469,
#     'good_frames': 334,
#     'drop_percent': 0.2878464818763326}},
#   'left_upper_shoabd': {'024': {'total_frames': 245,
#     'good_frames': 202,
#     'drop_percent': 0.17551020408163265},
#    '034': {'total_frames': 359,
#     'good_frames': 300,
#     'drop_percent': 0.16434540389972144},
#    '002': {'total_frames': 364,
#     'good_frames': 240,
#     'drop_percent': 0.34065934065934067},
#    '025': {'total_frames': 258,
#     'good_frames': 227,
#     'drop_percent': 0.12015503875968993},
#    '031': {'total_frames': 312,
#     'good_frames': 252,
#     'drop_percent': 0.19230769230769232},
#    '012': {'total_frames': 386,
#     'good_frames': 379,
#     'drop_percent': 0.018134715025906734},
#    '008': {'total_frames': 515,
#     'good_frames': 346,
#     'drop_percent': 0.32815533980582523},
#    '032': {'total_frames': 349,
#     'good_frames': 308,
#     'drop_percent': 0.1174785100286533},
#    '015': {'total_frames': 475,
#     'good_frames': 451,
#     'drop_percent': 0.05052631578947368},
#    '033': {'total_frames': 353,
#     'good_frames': 302,
#     'drop_percent': 0.14447592067988668},
#    '027': {'total_frames': 294,
#     'good_frames': 242,
#     'drop_percent': 0.17687074829931973},
#    '004': {'total_frames': 409,
#     'good_frames': 120,
#     'drop_percent': 0.706601466992665},
#    '011': {'total_frames': 391,
#     'good_frames': 301,
#     'drop_percent': 0.23017902813299232},
#    '006': {'total_frames': 400, 'good_frames': 227, 'drop_percent': 0.4325},
#    '029': {'total_frames': 300,
#     'good_frames': 241,
#     'drop_percent': 0.19666666666666666},
#    '030': {'total_frames': 307,
#     'good_frames': 258,
#     'drop_percent': 0.15960912052117263},
#    '022': {'total_frames': 292,
#     'good_frames': 260,
#     'drop_percent': 0.1095890410958904},
#    '007': {'total_frames': 415,
#     'good_frames': 146,
#     'drop_percent': 0.6481927710843374},
#    '005': {'total_frames': 204,
#     'good_frames': 112,
#     'drop_percent': 0.45098039215686275},
#    '014': {'total_frames': 405,
#     'good_frames': 344,
#     'drop_percent': 0.1506172839506173},
#    '013': {'total_frames': 411,
#     'good_frames': 275,
#     'drop_percent': 0.3309002433090024},
#    '028': {'total_frames': 354,
#     'good_frames': 300,
#     'drop_percent': 0.15254237288135594},
#    '001': {'total_frames': 329,
#     'good_frames': 142,
#     'drop_percent': 0.5683890577507599},
#    '009': {'total_frames': 368,
#     'good_frames': 191,
#     'drop_percent': 0.48097826086956524},
#    '003': {'total_frames': 415,
#     'good_frames': 152,
#     'drop_percent': 0.6337349397590362},
#    '021': {'total_frames': 282,
#     'good_frames': 256,
#     'drop_percent': 0.09219858156028368},
#    '010': {'total_frames': 419,
#     'good_frames': 179,
#     'drop_percent': 0.5727923627684964},
#    '026': {'total_frames': 288,
#     'good_frames': 251,
#     'drop_percent': 0.1284722222222222},
#    '023': {'total_frames': 282,
#     'good_frames': 247,
#     'drop_percent': 0.12411347517730496}},
#   'right_upper_shoabd': {'010': {'total_frames': 396,
#     'good_frames': 340,
#     'drop_percent': 0.1414141414141414},
#    '027': {'total_frames': 362,
#     'good_frames': 278,
#     'drop_percent': 0.23204419889502761},
#    '009': {'total_frames': 403,
#     'good_frames': 300,
#     'drop_percent': 0.2555831265508685},
#    '023': {'total_frames': 349,
#     'good_frames': 231,
#     'drop_percent': 0.33810888252148996},
#    '002': {'total_frames': 453,
#     'good_frames': 302,
#     'drop_percent': 0.3333333333333333},
#    '025': {'total_frames': 348,
#     'good_frames': 234,
#     'drop_percent': 0.3275862068965517},
#    '007': {'total_frames': 382,
#     'good_frames': 265,
#     'drop_percent': 0.306282722513089},
#    '028': {'total_frames': 304,
#     'good_frames': 240,
#     'drop_percent': 0.21052631578947367},
#    '030': {'total_frames': 302,
#     'good_frames': 241,
#     'drop_percent': 0.20198675496688742},
#    '001': {'total_frames': 371,
#     'good_frames': 295,
#     'drop_percent': 0.20485175202156333},
#    '020': {'total_frames': 302,
#     'good_frames': 181,
#     'drop_percent': 0.40066225165562913},
#    '004': {'total_frames': 395,
#     'good_frames': 287,
#     'drop_percent': 0.27341772151898736},
#    '021': {'total_frames': 341,
#     'good_frames': 190,
#     'drop_percent': 0.44281524926686217},
#    '026': {'total_frames': 357,
#     'good_frames': 243,
#     'drop_percent': 0.31932773109243695},
#    '011': {'total_frames': 401,
#     'good_frames': 370,
#     'drop_percent': 0.0773067331670823},
#    '003': {'total_frames': 418,
#     'good_frames': 309,
#     'drop_percent': 0.2607655502392344},
#    '008': {'total_frames': 403,
#     'good_frames': 333,
#     'drop_percent': 0.17369727047146402},
#    '022': {'total_frames': 366,
#     'good_frames': 242,
#     'drop_percent': 0.33879781420765026},
#    '029': {'total_frames': 339,
#     'good_frames': 146,
#     'drop_percent': 0.5693215339233039},
#    '024': {'total_frames': 340,
#     'good_frames': 167,
#     'drop_percent': 0.5088235294117647}},
#   'right_upper_shoext': {'001': {'total_frames': 372,
#     'good_frames': 328,
#     'drop_percent': 0.11827956989247312},
#    '021': {'total_frames': 402,
#     'good_frames': 271,
#     'drop_percent': 0.32587064676616917},
#    '024': {'total_frames': 372,
#     'good_frames': 281,
#     'drop_percent': 0.2446236559139785},
#    '020': {'total_frames': 382,
#     'good_frames': 205,
#     'drop_percent': 0.46335078534031415},
#    '010': {'total_frames': 370,
#     'good_frames': 322,
#     'drop_percent': 0.12972972972972974},
#    '026': {'total_frames': 356,
#     'good_frames': 200,
#     'drop_percent': 0.43820224719101125},
#    '011': {'total_frames': 348,
#     'good_frames': 233,
#     'drop_percent': 0.33045977011494254},
#    '022': {'total_frames': 341,
#     'good_frames': 183,
#     'drop_percent': 0.4633431085043988},
#    '028': {'total_frames': 410,
#     'good_frames': 206,
#     'drop_percent': 0.4975609756097561},
#    '009': {'total_frames': 402,
#     'good_frames': 365,
#     'drop_percent': 0.09203980099502487},
#    '033': {'total_frames': 366,
#     'good_frames': 185,
#     'drop_percent': 0.49453551912568305},
#    '025': {'total_frames': 391,
#     'good_frames': 249,
#     'drop_percent': 0.3631713554987212},
#    '023': {'total_frames': 348,
#     'good_frames': 171,
#     'drop_percent': 0.5086206896551724},
#    '006': {'total_frames': 399,
#     'good_frames': 281,
#     'drop_percent': 0.2957393483709273},
#    '032': {'total_frames': 323,
#     'good_frames': 173,
#     'drop_percent': 0.46439628482972134},
#    '027': {'total_frames': 380,
#     'good_frames': 188,
#     'drop_percent': 0.5052631578947369},
#    '002': {'total_frames': 438,
#     'good_frames': 360,
#     'drop_percent': 0.1780821917808219},
#    '004': {'total_frames': 359,
#     'good_frames': 291,
#     'drop_percent': 0.1894150417827298},
#    '007': {'total_frames': 425,
#     'good_frames': 416,
#     'drop_percent': 0.021176470588235293},
#    '003': {'total_frames': 409,
#     'good_frames': 363,
#     'drop_percent': 0.11246943765281174},
#    '030': {'total_frames': 321,
#     'good_frames': 167,
#     'drop_percent': 0.4797507788161994},
#    '008': {'total_frames': 357,
#     'good_frames': 305,
#     'drop_percent': 0.14565826330532214},
#    '029': {'total_frames': 362,
#     'good_frames': 203,
#     'drop_percent': 0.43922651933701656},
#    '031': {'total_frames': 350,
#     'good_frames': 209,
#     'drop_percent': 0.40285714285714286},
#    '005': {'total_frames': 384,
#     'good_frames': 351,
#     'drop_percent': 0.0859375}},
#   'left_upper_shoext': {'028': {'total_frames': 318,
#     'good_frames': 256,
#     'drop_percent': 0.1949685534591195},
#    '001': {'total_frames': 305,
#     'good_frames': 299,
#     'drop_percent': 0.019672131147540985},
#    '011': {'total_frames': 353,
#     'good_frames': 331,
#     'drop_percent': 0.06232294617563739},
#    '002': {'total_frames': 389,
#     'good_frames': 349,
#     'drop_percent': 0.10282776349614396},
#    '029': {'total_frames': 336,
#     'good_frames': 274,
#     'drop_percent': 0.18452380952380953},
#    '006': {'total_frames': 371,
#     'good_frames': 345,
#     'drop_percent': 0.07008086253369272},
#    '027': {'total_frames': 288,
#     'good_frames': 266,
#     'drop_percent': 0.0763888888888889},
#    '004': {'total_frames': 322,
#     'good_frames': 211,
#     'drop_percent': 0.3447204968944099},
#    '020': {'total_frames': 280,
#     'good_frames': 205,
#     'drop_percent': 0.26785714285714285},
#    '007': {'total_frames': 411,
#     'good_frames': 352,
#     'drop_percent': 0.1435523114355231},
#    '033': {'total_frames': 323,
#     'good_frames': 288,
#     'drop_percent': 0.10835913312693499},
#    '005': {'total_frames': 332,
#     'good_frames': 279,
#     'drop_percent': 0.15963855421686746},
#    '008': {'total_frames': 462,
#     'good_frames': 350,
#     'drop_percent': 0.24242424242424243},
#    '024': {'total_frames': 378,
#     'good_frames': 341,
#     'drop_percent': 0.09788359788359788},
#    '010': {'total_frames': 384,
#     'good_frames': 359,
#     'drop_percent': 0.06510416666666667},
#    '026': {'total_frames': 312,
#     'good_frames': 268,
#     'drop_percent': 0.14102564102564102},
#    '025': {'total_frames': 335, 'good_frames': 268, 'drop_percent': 0.2},
#    '032': {'total_frames': 332,
#     'good_frames': 326,
#     'drop_percent': 0.018072289156626505},
#    '021': {'total_frames': 319,
#     'good_frames': 260,
#     'drop_percent': 0.18495297805642633},
#    '031': {'total_frames': 365,
#     'good_frames': 293,
#     'drop_percent': 0.19726027397260273},
#    '009': {'total_frames': 389,
#     'good_frames': 224,
#     'drop_percent': 0.4241645244215938},
#    '030': {'total_frames': 359,
#     'good_frames': 354,
#     'drop_percent': 0.013927576601671309},
#    '034': {'total_frames': 374,
#     'good_frames': 223,
#     'drop_percent': 0.4037433155080214},
#    '023': {'total_frames': 325,
#     'good_frames': 294,
#     'drop_percent': 0.09538461538461539},
#    '022': {'total_frames': 334,
#     'good_frames': 298,
#     'drop_percent': 0.10778443113772455},
#    '003': {'total_frames': 330,
#     'good_frames': 267,
#     'drop_percent': 0.19090909090909092}},
#   'left_upper_shoflex': {'001': {'total_frames': 394,
#     'good_frames': 348,
#     'drop_percent': 0.116751269035533},
#    '030': {'total_frames': 367,
#     'good_frames': 86,
#     'drop_percent': 0.7656675749318801},
#    '021': {'total_frames': 317,
#     'good_frames': 210,
#     'drop_percent': 0.33753943217665616},
#    '006': {'total_frames': 311,
#     'good_frames': 202,
#     'drop_percent': 0.3504823151125402},
#    '020': {'total_frames': 298,
#     'good_frames': 212,
#     'drop_percent': 0.28859060402684567},
#    '004': {'total_frames': 364,
#     'good_frames': 284,
#     'drop_percent': 0.21978021978021978},
#    '027': {'total_frames': 361,
#     'good_frames': 186,
#     'drop_percent': 0.48476454293628807},
#    '032': {'total_frames': 350, 'good_frames': 140, 'drop_percent': 0.6},
#    '010': {'total_frames': 352,
#     'good_frames': 225,
#     'drop_percent': 0.36079545454545453},
#    '033': {'total_frames': 356,
#     'good_frames': 79,
#     'drop_percent': 0.7780898876404494},
#    '029': {'total_frames': 379,
#     'good_frames': 85,
#     'drop_percent': 0.7757255936675461},
#    '025': {'total_frames': 362,
#     'good_frames': 212,
#     'drop_percent': 0.4143646408839779},
#    '002': {'total_frames': 382,
#     'good_frames': 218,
#     'drop_percent': 0.4293193717277487},
#    '028': {'total_frames': 362,
#     'good_frames': 180,
#     'drop_percent': 0.5027624309392266},
#    '003': {'total_frames': 414,
#     'good_frames': 287,
#     'drop_percent': 0.30676328502415456},
#    '026': {'total_frames': 342,
#     'good_frames': 253,
#     'drop_percent': 0.260233918128655},
#    '023': {'total_frames': 325,
#     'good_frames': 171,
#     'drop_percent': 0.47384615384615386},
#    '005': {'total_frames': 413,
#     'good_frames': 291,
#     'drop_percent': 0.29539951573849876},
#    '031': {'total_frames': 326,
#     'good_frames': 96,
#     'drop_percent': 0.7055214723926381},
#    '008': {'total_frames': 412,
#     'good_frames': 314,
#     'drop_percent': 0.23786407766990292},
#    '022': {'total_frames': 361,
#     'good_frames': 278,
#     'drop_percent': 0.2299168975069252},
#    '024': {'total_frames': 315,
#     'good_frames': 136,
#     'drop_percent': 0.5682539682539682},
#    '007': {'total_frames': 356,
#     'good_frames': 283,
#     'drop_percent': 0.2050561797752809},
#    '009': {'total_frames': 380,
#     'good_frames': 265,
#     'drop_percent': 0.3026315789473684},
#    '034': {'total_frames': 359,
#     'good_frames': 127,
#     'drop_percent': 0.6462395543175488}},
#   'right_upper_shoflex': {'025': {'total_frames': 331,
#     'good_frames': 235,
#     'drop_percent': 0.29003021148036257},
#    '031': {'total_frames': 279,
#     'good_frames': 173,
#     'drop_percent': 0.37992831541218636},
#    '030': {'total_frames': 324,
#     'good_frames': 157,
#     'drop_percent': 0.5154320987654321},
#    '021': {'total_frames': 303,
#     'good_frames': 145,
#     'drop_percent': 0.5214521452145214},
#    '022': {'total_frames': 303,
#     'good_frames': 189,
#     'drop_percent': 0.37623762376237624},
#    '004': {'total_frames': 395,
#     'good_frames': 281,
#     'drop_percent': 0.28860759493670884},
#    '002': {'total_frames': 377,
#     'good_frames': 261,
#     'drop_percent': 0.3076923076923077},
#    '009': {'total_frames': 390,
#     'good_frames': 279,
#     'drop_percent': 0.2846153846153846},
#    '024': {'total_frames': 368,
#     'good_frames': 240,
#     'drop_percent': 0.34782608695652173},
#    '020': {'total_frames': 320, 'good_frames': 229, 'drop_percent': 0.284375},
#    '023': {'total_frames': 362,
#     'good_frames': 293,
#     'drop_percent': 0.19060773480662985},
#    '029': {'total_frames': 356,
#     'good_frames': 202,
#     'drop_percent': 0.43258426966292135},
#    '006': {'total_frames': 435,
#     'good_frames': 258,
#     'drop_percent': 0.4068965517241379},
#    '003': {'total_frames': 397,
#     'good_frames': 271,
#     'drop_percent': 0.31738035264483627},
#    '008': {'total_frames': 437,
#     'good_frames': 314,
#     'drop_percent': 0.2814645308924485},
#    '005': {'total_frames': 389,
#     'good_frames': 218,
#     'drop_percent': 0.43958868894601544},
#    '026': {'total_frames': 358,
#     'good_frames': 235,
#     'drop_percent': 0.3435754189944134},
#    '032': {'total_frames': 301,
#     'good_frames': 230,
#     'drop_percent': 0.23588039867109634},
#    '027': {'total_frames': 311,
#     'good_frames': 167,
#     'drop_percent': 0.4630225080385852},
#    '007': {'total_frames': 395,
#     'good_frames': 292,
#     'drop_percent': 0.2607594936708861},
#    '010': {'total_frames': 380,
#     'good_frames': 250,
#     'drop_percent': 0.34210526315789475},
#    '011': {'total_frames': 384,
#     'good_frames': 265,
#     'drop_percent': 0.3098958333333333},
#    '028': {'total_frames': 368,
#     'good_frames': 168,
#     'drop_percent': 0.5434782608695652}}},
#  'dl205': {'right_upper_elbflex': {'011': {'total_frames': 444,
#     'good_frames': 444,
#     'drop_percent': 0.0},
#    '008': {'total_frames': 409, 'good_frames': 409, 'drop_percent': 0.0},
#    '005': {'total_frames': 471, 'good_frames': 471, 'drop_percent': 0.0},
#    '002': {'total_frames': 354,
#     'good_frames': 353,
#     'drop_percent': 0.002824858757062147},
#    '010': {'total_frames': 427, 'good_frames': 427, 'drop_percent': 0.0},
#    '020': {'total_frames': 386, 'good_frames': 386, 'drop_percent': 0.0},
#    '019': {'total_frames': 414,
#     'good_frames': 412,
#     'drop_percent': 0.004830917874396135},
#    '006': {'total_frames': 412, 'good_frames': 412, 'drop_percent': 0.0},
#    '017': {'total_frames': 482, 'good_frames': 482, 'drop_percent': 0.0},
#    '016': {'total_frames': 436,
#     'good_frames': 434,
#     'drop_percent': 0.0045871559633027525},
#    '009': {'total_frames': 452,
#     'good_frames': 449,
#     'drop_percent': 0.00663716814159292},
#    '003': {'total_frames': 400, 'good_frames': 400, 'drop_percent': 0.0},
#    '012': {'total_frames': 382,
#     'good_frames': 381,
#     'drop_percent': 0.002617801047120419},
#    '014': {'total_frames': 427,
#     'good_frames': 426,
#     'drop_percent': 0.00234192037470726},
#    '015': {'total_frames': 441,
#     'good_frames': 439,
#     'drop_percent': 0.0045351473922902496},
#    '007': {'total_frames': 431,
#     'good_frames': 430,
#     'drop_percent': 0.002320185614849188},
#    '001': {'total_frames': 405, 'good_frames': 405, 'drop_percent': 0.0},
#    '018': {'total_frames': 409,
#     'good_frames': 408,
#     'drop_percent': 0.0024449877750611247},
#    '004': {'total_frames': 390,
#     'good_frames': 388,
#     'drop_percent': 0.005128205128205128},
#    '013': {'total_frames': 430, 'good_frames': 430, 'drop_percent': 0.0}},
#   'left_upper_elbflex': {'016': {'total_frames': 428,
#     'good_frames': 418,
#     'drop_percent': 0.02336448598130841},
#    '004': {'total_frames': 449,
#     'good_frames': 444,
#     'drop_percent': 0.011135857461024499},
#    '008': {'total_frames': 459,
#     'good_frames': 440,
#     'drop_percent': 0.04139433551198257},
#    '007': {'total_frames': 436,
#     'good_frames': 425,
#     'drop_percent': 0.02522935779816514},
#    '011': {'total_frames': 430,
#     'good_frames': 413,
#     'drop_percent': 0.03953488372093023},
#    '014': {'total_frames': 412,
#     'good_frames': 405,
#     'drop_percent': 0.01699029126213592},
#    '009': {'total_frames': 418,
#     'good_frames': 415,
#     'drop_percent': 0.007177033492822967},
#    '012': {'total_frames': 466,
#     'good_frames': 458,
#     'drop_percent': 0.017167381974248927},
#    '001': {'total_frames': 407,
#     'good_frames': 393,
#     'drop_percent': 0.0343980343980344},
#    '002': {'total_frames': 396, 'good_frames': 396, 'drop_percent': 0.0},
#    '015': {'total_frames': 407,
#     'good_frames': 400,
#     'drop_percent': 0.0171990171990172},
#    '013': {'total_frames': 375, 'good_frames': 369, 'drop_percent': 0.016},
#    '017': {'total_frames': 435,
#     'good_frames': 428,
#     'drop_percent': 0.016091954022988506},
#    '010': {'total_frames': 541,
#     'good_frames': 526,
#     'drop_percent': 0.027726432532347505},
#    '005': {'total_frames': 427,
#     'good_frames': 419,
#     'drop_percent': 0.01873536299765808},
#    '003': {'total_frames': 428,
#     'good_frames': 400,
#     'drop_percent': 0.06542056074766354},
#    '006': {'total_frames': 476,
#     'good_frames': 472,
#     'drop_percent': 0.008403361344537815}},
#   'left_upper_shoabd': {'010': {'total_frames': 473,
#     'good_frames': 318,
#     'drop_percent': 0.3276955602536998},
#    '003': {'total_frames': 475, 'good_frames': 323, 'drop_percent': 0.32},
#    '011': {'total_frames': 446,
#     'good_frames': 319,
#     'drop_percent': 0.28475336322869954},
#    '007': {'total_frames': 448,
#     'good_frames': 365,
#     'drop_percent': 0.18526785714285715},
#    '014': {'total_frames': 491,
#     'good_frames': 286,
#     'drop_percent': 0.4175152749490835},
#    '008': {'total_frames': 451,
#     'good_frames': 390,
#     'drop_percent': 0.1352549889135255},
#    '001': {'total_frames': 451,
#     'good_frames': 307,
#     'drop_percent': 0.31929046563192903},
#    '006': {'total_frames': 435,
#     'good_frames': 267,
#     'drop_percent': 0.38620689655172413},
#    '020': {'total_frames': 456,
#     'good_frames': 275,
#     'drop_percent': 0.3969298245614035},
#    '009': {'total_frames': 454,
#     'good_frames': 333,
#     'drop_percent': 0.2665198237885463},
#    '019': {'total_frames': 470,
#     'good_frames': 371,
#     'drop_percent': 0.21063829787234042},
#    '015': {'total_frames': 497,
#     'good_frames': 366,
#     'drop_percent': 0.2635814889336016},
#    '012': {'total_frames': 450,
#     'good_frames': 358,
#     'drop_percent': 0.20444444444444446},
#    '013': {'total_frames': 487,
#     'good_frames': 372,
#     'drop_percent': 0.23613963039014374},
#    '016': {'total_frames': 417,
#     'good_frames': 347,
#     'drop_percent': 0.16786570743405277},
#    '005': {'total_frames': 419,
#     'good_frames': 370,
#     'drop_percent': 0.11694510739856802},
#    '004': {'total_frames': 525,
#     'good_frames': 319,
#     'drop_percent': 0.3923809523809524},
#    '018': {'total_frames': 486,
#     'good_frames': 423,
#     'drop_percent': 0.12962962962962962},
#    '002': {'total_frames': 483,
#     'good_frames': 299,
#     'drop_percent': 0.38095238095238093},
#    '017': {'total_frames': 423,
#     'good_frames': 292,
#     'drop_percent': 0.30969267139479906}},
#   'right_upper_shoabd': {'014': {'total_frames': 502,
#     'good_frames': 327,
#     'drop_percent': 0.34860557768924305},
#    '003': {'total_frames': 522,
#     'good_frames': 423,
#     'drop_percent': 0.1896551724137931},
#    '018': {'total_frames': 545,
#     'good_frames': 363,
#     'drop_percent': 0.3339449541284404},
#    '015': {'total_frames': 537,
#     'good_frames': 394,
#     'drop_percent': 0.26629422718808193},
#    '019': {'total_frames': 525,
#     'good_frames': 397,
#     'drop_percent': 0.2438095238095238},
#    '010': {'total_frames': 515,
#     'good_frames': 330,
#     'drop_percent': 0.3592233009708738},
#    '017': {'total_frames': 535,
#     'good_frames': 421,
#     'drop_percent': 0.2130841121495327},
#    '013': {'total_frames': 502,
#     'good_frames': 326,
#     'drop_percent': 0.350597609561753},
#    '020': {'total_frames': 549,
#     'good_frames': 290,
#     'drop_percent': 0.47176684881602915},
#    '004': {'total_frames': 500, 'good_frames': 367, 'drop_percent': 0.266},
#    '016': {'total_frames': 479,
#     'good_frames': 378,
#     'drop_percent': 0.21085594989561587},
#    '001': {'total_frames': 520,
#     'good_frames': 405,
#     'drop_percent': 0.22115384615384615},
#    '009': {'total_frames': 521,
#     'good_frames': 417,
#     'drop_percent': 0.19961612284069097},
#    '011': {'total_frames': 484,
#     'good_frames': 335,
#     'drop_percent': 0.30785123966942146},
#    '007': {'total_frames': 503,
#     'good_frames': 367,
#     'drop_percent': 0.27037773359840955},
#    '005': {'total_frames': 535,
#     'good_frames': 374,
#     'drop_percent': 0.30093457943925234},
#    '008': {'total_frames': 488,
#     'good_frames': 331,
#     'drop_percent': 0.32172131147540983},
#    '002': {'total_frames': 488,
#     'good_frames': 447,
#     'drop_percent': 0.08401639344262295},
#    '012': {'total_frames': 527,
#     'good_frames': 371,
#     'drop_percent': 0.29601518026565465},
#    '006': {'total_frames': 501,
#     'good_frames': 309,
#     'drop_percent': 0.38323353293413176}},
#   'right_upper_shoext': {'005': {'total_frames': 399,
#     'good_frames': 399,
#     'drop_percent': 0.0},
#    '003': {'total_frames': 400, 'good_frames': 399, 'drop_percent': 0.0025},
#    '019': {'total_frames': 491, 'good_frames': 491, 'drop_percent': 0.0},
#    '015': {'total_frames': 496,
#     'good_frames': 481,
#     'drop_percent': 0.03024193548387097},
#    '012': {'total_frames': 465, 'good_frames': 465, 'drop_percent': 0.0},
#    '010': {'total_frames': 472, 'good_frames': 472, 'drop_percent': 0.0},
#    '017': {'total_frames': 469,
#     'good_frames': 468,
#     'drop_percent': 0.0021321961620469083},
#    '007': {'total_frames': 378,
#     'good_frames': 377,
#     'drop_percent': 0.0026455026455026454},
#    '004': {'total_frames': 468, 'good_frames': 468, 'drop_percent': 0.0},
#    '018': {'total_frames': 487, 'good_frames': 487, 'drop_percent': 0.0},
#    '013': {'total_frames': 531, 'good_frames': 531, 'drop_percent': 0.0},
#    '009': {'total_frames': 443, 'good_frames': 443, 'drop_percent': 0.0},
#    '001': {'total_frames': 394,
#     'good_frames': 393,
#     'drop_percent': 0.0025380710659898475},
#    '016': {'total_frames': 501, 'good_frames': 501, 'drop_percent': 0.0},
#    '002': {'total_frames': 389,
#     'good_frames': 358,
#     'drop_percent': 0.07969151670951156},
#    '006': {'total_frames': 467, 'good_frames': 467, 'drop_percent': 0.0},
#    '011': {'total_frames': 413, 'good_frames': 413, 'drop_percent': 0.0},
#    '008': {'total_frames': 430, 'good_frames': 430, 'drop_percent': 0.0},
#    '014': {'total_frames': 470, 'good_frames': 470, 'drop_percent': 0.0},
#    '020': {'total_frames': 466, 'good_frames': 466, 'drop_percent': 0.0}},
#   'left_upper_shoext': {'010': {'total_frames': 434,
#     'good_frames': 432,
#     'drop_percent': 0.004608294930875576},
#    '007': {'total_frames': 463,
#     'good_frames': 439,
#     'drop_percent': 0.05183585313174946},
#    '018': {'total_frames': 396,
#     'good_frames': 386,
#     'drop_percent': 0.025252525252525252},
#    '012': {'total_frames': 448,
#     'good_frames': 442,
#     'drop_percent': 0.013392857142857142},
#    '014': {'total_frames': 410,
#     'good_frames': 367,
#     'drop_percent': 0.1048780487804878},
#    '011': {'total_frames': 389,
#     'good_frames': 386,
#     'drop_percent': 0.007712082262210797},
#    '003': {'total_frames': 397, 'good_frames': 397, 'drop_percent': 0.0},
#    '019': {'total_frames': 427,
#     'good_frames': 418,
#     'drop_percent': 0.02107728337236534},
#    '013': {'total_frames': 412,
#     'good_frames': 406,
#     'drop_percent': 0.014563106796116505},
#    '020': {'total_frames': 435,
#     'good_frames': 429,
#     'drop_percent': 0.013793103448275862},
#    '016': {'total_frames': 438,
#     'good_frames': 437,
#     'drop_percent': 0.00228310502283105},
#    '004': {'total_frames': 378,
#     'good_frames': 369,
#     'drop_percent': 0.023809523809523808},
#    '006': {'total_frames': 485,
#     'good_frames': 470,
#     'drop_percent': 0.030927835051546393},
#    '015': {'total_frames': 359, 'good_frames': 359, 'drop_percent': 0.0},
#    '002': {'total_frames': 418,
#     'good_frames': 407,
#     'drop_percent': 0.02631578947368421},
#    '008': {'total_frames': 366,
#     'good_frames': 348,
#     'drop_percent': 0.04918032786885246},
#    '005': {'total_frames': 422,
#     'good_frames': 420,
#     'drop_percent': 0.004739336492890996},
#    '009': {'total_frames': 391,
#     'good_frames': 373,
#     'drop_percent': 0.04603580562659847},
#    '017': {'total_frames': 386, 'good_frames': 386, 'drop_percent': 0.0},
#    '001': {'total_frames': 341,
#     'good_frames': 310,
#     'drop_percent': 0.09090909090909091}},
#   'right_upper_shoflex': {'012': {'total_frames': 485,
#     'good_frames': 452,
#     'drop_percent': 0.06804123711340206},
#    '002': {'total_frames': 477,
#     'good_frames': 394,
#     'drop_percent': 0.1740041928721174},
#    '001': {'total_frames': 477,
#     'good_frames': 380,
#     'drop_percent': 0.20335429769392033},
#    '018': {'total_frames': 488,
#     'good_frames': 483,
#     'drop_percent': 0.010245901639344262},
#    '019': {'total_frames': 444,
#     'good_frames': 438,
#     'drop_percent': 0.013513513513513514},
#    '009': {'total_frames': 566,
#     'good_frames': 563,
#     'drop_percent': 0.00530035335689046},
#    '006': {'total_frames': 439,
#     'good_frames': 437,
#     'drop_percent': 0.004555808656036446},
#    '004': {'total_frames': 460,
#     'good_frames': 458,
#     'drop_percent': 0.004347826086956522},
#    '008': {'total_frames': 496,
#     'good_frames': 485,
#     'drop_percent': 0.02217741935483871},
#    '007': {'total_frames': 481,
#     'good_frames': 479,
#     'drop_percent': 0.004158004158004158},
#    '016': {'total_frames': 468,
# ...
#     'good_frames': 289,
#     'drop_percent': 0.09404388714733543},
#    '012': {'total_frames': 371,
#     'good_frames': 314,
#     'drop_percent': 0.15363881401617252},
#    '005': {'total_frames': 327,
#     'good_frames': 299,
#     'drop_percent': 0.0856269113149847}}},
#  'dl204': {'left_upper_elbflex': {'020': {'total_frames': 550,
#     'good_frames': 438,
#     'drop_percent': 0.20363636363636364},
#    '004': {'total_frames': 315,
#     'good_frames': 238,
#     'drop_percent': 0.24444444444444444},
#    '012': {'total_frames': 390,
#     'good_frames': 286,
#     'drop_percent': 0.26666666666666666},
#    '005': {'total_frames': 457,
#     'good_frames': 358,
#     'drop_percent': 0.21663019693654267},
#    '002': {'total_frames': 338,
#     'good_frames': 258,
#     'drop_percent': 0.23668639053254437},
#    '008': {'total_frames': 392,
#     'good_frames': 323,
#     'drop_percent': 0.1760204081632653},
#    '006': {'total_frames': 344,
#     'good_frames': 245,
#     'drop_percent': 0.2877906976744186},
#    '014': {'total_frames': 371,
#     'good_frames': 271,
#     'drop_percent': 0.2695417789757412},
#    '011': {'total_frames': 392,
#     'good_frames': 260,
#     'drop_percent': 0.336734693877551},
#    '010': {'total_frames': 353,
#     'good_frames': 272,
#     'drop_percent': 0.22946175637393768},
#    '001': {'total_frames': 296,
#     'good_frames': 224,
#     'drop_percent': 0.24324324324324326},
#    '015': {'total_frames': 364,
#     'good_frames': 268,
#     'drop_percent': 0.26373626373626374},
#    '003': {'total_frames': 335,
#     'good_frames': 259,
#     'drop_percent': 0.22686567164179106},
#    '018': {'total_frames': 380, 'good_frames': 285, 'drop_percent': 0.25},
#    '007': {'total_frames': 354,
#     'good_frames': 251,
#     'drop_percent': 0.2909604519774011},
#    '009': {'total_frames': 355,
#     'good_frames': 276,
#     'drop_percent': 0.22253521126760564},
#    '013': {'total_frames': 376,
#     'good_frames': 211,
#     'drop_percent': 0.43882978723404253},
#    '019': {'total_frames': 412,
#     'good_frames': 315,
#     'drop_percent': 0.2354368932038835},
#    '017': {'total_frames': 369,
#     'good_frames': 278,
#     'drop_percent': 0.24661246612466126},
#    '016': {'total_frames': 390,
#     'good_frames': 295,
#     'drop_percent': 0.24358974358974358}},
#   'right_upper_elbflex': {'019': {'total_frames': 441,
#     'good_frames': 279,
#     'drop_percent': 0.3673469387755102},
#    '008': {'total_frames': 379,
#     'good_frames': 291,
#     'drop_percent': 0.23218997361477572},
#    '014': {'total_frames': 371,
#     'good_frames': 282,
#     'drop_percent': 0.2398921832884097},
#    '011': {'total_frames': 357,
#     'good_frames': 282,
#     'drop_percent': 0.21008403361344538},
#    '017': {'total_frames': 383,
#     'good_frames': 236,
#     'drop_percent': 0.3838120104438642},
#    '020': {'total_frames': 413,
#     'good_frames': 289,
#     'drop_percent': 0.30024213075060535},
#    '007': {'total_frames': 362,
#     'good_frames': 267,
#     'drop_percent': 0.26243093922651933},
#    '005': {'total_frames': 364, 'good_frames': 273, 'drop_percent': 0.25},
#    '016': {'total_frames': 388,
#     'good_frames': 277,
#     'drop_percent': 0.2860824742268041},
#    '012': {'total_frames': 382,
#     'good_frames': 300,
#     'drop_percent': 0.21465968586387435},
#    '015': {'total_frames': 371,
#     'good_frames': 238,
#     'drop_percent': 0.3584905660377358},
#    '018': {'total_frames': 392,
#     'good_frames': 287,
#     'drop_percent': 0.26785714285714285},
#    '004': {'total_frames': 364,
#     'good_frames': 281,
#     'drop_percent': 0.22802197802197802},
#    '003': {'total_frames': 324,
#     'good_frames': 227,
#     'drop_percent': 0.2993827160493827},
#    '009': {'total_frames': 365,
#     'good_frames': 284,
#     'drop_percent': 0.2219178082191781},
#    '002': {'total_frames': 363,
#     'good_frames': 263,
#     'drop_percent': 0.27548209366391185},
#    '010': {'total_frames': 351,
#     'good_frames': 271,
#     'drop_percent': 0.22792022792022792},
#    '001': {'total_frames': 342,
#     'good_frames': 265,
#     'drop_percent': 0.22514619883040934},
#    '006': {'total_frames': 384,
#     'good_frames': 265,
#     'drop_percent': 0.3098958333333333},
#    '013': {'total_frames': 363,
#     'good_frames': 291,
#     'drop_percent': 0.19834710743801653}},
#   'right_upper_shoabd': {'003': {'total_frames': 346,
#     'good_frames': 218,
#     'drop_percent': 0.3699421965317919},
#    '013': {'total_frames': 386,
#     'good_frames': 280,
#     'drop_percent': 0.27461139896373055},
#    '009': {'total_frames': 390,
#     'good_frames': 284,
#     'drop_percent': 0.2717948717948718},
#    '005': {'total_frames': 387,
#     'good_frames': 276,
#     'drop_percent': 0.2868217054263566},
#    '010': {'total_frames': 372,
#     'good_frames': 283,
#     'drop_percent': 0.239247311827957},
#    '008': {'total_frames': 387,
#     'good_frames': 289,
#     'drop_percent': 0.2532299741602067},
#    '018': {'total_frames': 391,
#     'good_frames': 237,
#     'drop_percent': 0.3938618925831202},
#    '004': {'total_frames': 372,
#     'good_frames': 259,
#     'drop_percent': 0.30376344086021506},
#    '016': {'total_frames': 396,
#     'good_frames': 255,
#     'drop_percent': 0.3560606060606061},
#    '015': {'total_frames': 392,
#     'good_frames': 239,
#     'drop_percent': 0.3903061224489796},
#    '017': {'total_frames': 388,
#     'good_frames': 257,
#     'drop_percent': 0.33762886597938147},
#    '019': {'total_frames': 375,
#     'good_frames': 233,
#     'drop_percent': 0.37866666666666665},
#    '006': {'total_frames': 370,
#     'good_frames': 275,
#     'drop_percent': 0.25675675675675674},
#    '011': {'total_frames': 383,
#     'good_frames': 270,
#     'drop_percent': 0.2950391644908616},
#    '001': {'total_frames': 348,
#     'good_frames': 283,
#     'drop_percent': 0.1867816091954023},
#    '020': {'total_frames': 409,
#     'good_frames': 267,
#     'drop_percent': 0.3471882640586797},
#    '007': {'total_frames': 401,
#     'good_frames': 294,
#     'drop_percent': 0.26683291770573564},
#    '014': {'total_frames': 393,
#     'good_frames': 255,
#     'drop_percent': 0.3511450381679389},
#    '012': {'total_frames': 409,
#     'good_frames': 308,
#     'drop_percent': 0.2469437652811736},
#    '002': {'total_frames': 357,
#     'good_frames': 259,
#     'drop_percent': 0.27450980392156865}},
#   'left_upper_shoabd': {'006': {'total_frames': 316,
#     'good_frames': 279,
#     'drop_percent': 0.11708860759493671},
#    '012': {'total_frames': 328,
#     'good_frames': 312,
#     'drop_percent': 0.04878048780487805},
#    '011': {'total_frames': 345,
#     'good_frames': 337,
#     'drop_percent': 0.02318840579710145},
#    '004': {'total_frames': 342,
#     'good_frames': 332,
#     'drop_percent': 0.029239766081871343},
#    '007': {'total_frames': 352,
#     'good_frames': 338,
#     'drop_percent': 0.03977272727272727},
#    '017': {'total_frames': 401,
#     'good_frames': 379,
#     'drop_percent': 0.05486284289276808},
#    '020': {'total_frames': 373,
#     'good_frames': 300,
#     'drop_percent': 0.19571045576407506},
#    '015': {'total_frames': 376,
#     'good_frames': 347,
#     'drop_percent': 0.07712765957446809},
#    '002': {'total_frames': 303,
#     'good_frames': 293,
#     'drop_percent': 0.033003300330033},
#    '003': {'total_frames': 338,
#     'good_frames': 332,
#     'drop_percent': 0.01775147928994083},
#    '001': {'total_frames': 304,
#     'good_frames': 291,
#     'drop_percent': 0.04276315789473684},
#    '014': {'total_frames': 347,
#     'good_frames': 336,
#     'drop_percent': 0.03170028818443804},
#    '018': {'total_frames': 361,
#     'good_frames': 334,
#     'drop_percent': 0.07479224376731301},
#    '019': {'total_frames': 388,
#     'good_frames': 361,
#     'drop_percent': 0.06958762886597938},
#    '010': {'total_frames': 322,
#     'good_frames': 297,
#     'drop_percent': 0.07763975155279502},
#    '016': {'total_frames': 376,
#     'good_frames': 357,
#     'drop_percent': 0.05053191489361702},
#    '013': {'total_frames': 350,
#     'good_frames': 298,
#     'drop_percent': 0.14857142857142858},
#    '009': {'total_frames': 342,
#     'good_frames': 324,
#     'drop_percent': 0.05263157894736842},
#    '008': {'total_frames': 362,
#     'good_frames': 343,
#     'drop_percent': 0.052486187845303865},
#    '005': {'total_frames': 334,
#     'good_frames': 303,
#     'drop_percent': 0.09281437125748503}},
#   'right_upper_shoext': {'003': {'total_frames': 377,
#     'good_frames': 351,
#     'drop_percent': 0.06896551724137931},
#    '009': {'total_frames': 369,
#     'good_frames': 363,
#     'drop_percent': 0.016260162601626018},
#    '007': {'total_frames': 335,
#     'good_frames': 311,
#     'drop_percent': 0.07164179104477612},
#    '010': {'total_frames': 388,
#     'good_frames': 381,
#     'drop_percent': 0.01804123711340206},
#    '019': {'total_frames': 400, 'good_frames': 395, 'drop_percent': 0.0125},
#    '020': {'total_frames': 384,
#     'good_frames': 383,
#     'drop_percent': 0.0026041666666666665},
#    '008': {'total_frames': 360,
#     'good_frames': 355,
#     'drop_percent': 0.013888888888888888},
#    '018': {'total_frames': 399,
#     'good_frames': 383,
#     'drop_percent': 0.040100250626566414},
#    '016': {'total_frames': 405,
#     'good_frames': 399,
#     'drop_percent': 0.014814814814814815},
#    '017': {'total_frames': 392,
#     'good_frames': 385,
#     'drop_percent': 0.017857142857142856},
#    '006': {'total_frames': 370,
#     'good_frames': 361,
#     'drop_percent': 0.024324324324324326},
#    '015': {'total_frames': 390,
#     'good_frames': 381,
#     'drop_percent': 0.023076923076923078},
#    '001': {'total_frames': 285,
#     'good_frames': 280,
#     'drop_percent': 0.017543859649122806},
#    '004': {'total_frames': 359,
#     'good_frames': 354,
#     'drop_percent': 0.013927576601671309},
#    '005': {'total_frames': 383,
#     'good_frames': 377,
#     'drop_percent': 0.015665796344647518},
#    '011': {'total_frames': 404,
#     'good_frames': 402,
#     'drop_percent': 0.0049504950495049506},
#    '012': {'total_frames': 389,
#     'good_frames': 386,
#     'drop_percent': 0.007712082262210797},
#    '014': {'total_frames': 394,
#     'good_frames': 392,
#     'drop_percent': 0.005076142131979695},
#    '013': {'total_frames': 367,
#     'good_frames': 357,
#     'drop_percent': 0.027247956403269755},
#    '002': {'total_frames': 354,
#     'good_frames': 328,
#     'drop_percent': 0.07344632768361582}},
#   'left_upper_shoext': {'020': {'total_frames': 373,
#     'good_frames': 174,
#     'drop_percent': 0.5335120643431636},
#    '012': {'total_frames': 418,
#     'good_frames': 312,
#     'drop_percent': 0.2535885167464115},
#    '011': {'total_frames': 407,
#     'good_frames': 334,
#     'drop_percent': 0.17936117936117937},
#    '004': {'total_frames': 395,
#     'good_frames': 234,
#     'drop_percent': 0.40759493670886077},
#    '017': {'total_frames': 416,
#     'good_frames': 248,
#     'drop_percent': 0.40384615384615385},
#    '008': {'total_frames': 384,
#     'good_frames': 287,
#     'drop_percent': 0.2526041666666667},
#    '016': {'total_frames': 401,
#     'good_frames': 201,
#     'drop_percent': 0.49875311720698257},
#    '001': {'total_frames': 353,
#     'good_frames': 182,
#     'drop_percent': 0.48441926345609065},
#    '014': {'total_frames': 424,
#     'good_frames': 313,
#     'drop_percent': 0.2617924528301887},
#    '003': {'total_frames': 394,
#     'good_frames': 216,
#     'drop_percent': 0.4517766497461929},
#    '015': {'total_frames': 388,
#     'good_frames': 319,
#     'drop_percent': 0.17783505154639176},
#    '006': {'total_frames': 364,
#     'good_frames': 234,
#     'drop_percent': 0.35714285714285715},
#    '018': {'total_frames': 385,
#     'good_frames': 251,
#     'drop_percent': 0.34805194805194806},
#    '013': {'total_frames': 420,
#     'good_frames': 330,
#     'drop_percent': 0.21428571428571427},
#    '002': {'total_frames': 371,
#     'good_frames': 279,
#     'drop_percent': 0.24797843665768193},
#    '007': {'total_frames': 398,
#     'good_frames': 241,
#     'drop_percent': 0.3944723618090452},
#    '010': {'total_frames': 397,
#     'good_frames': 314,
#     'drop_percent': 0.20906801007556675},
#    '019': {'total_frames': 442,
#     'good_frames': 296,
#     'drop_percent': 0.33031674208144796},
#    '009': {'total_frames': 381,
#     'good_frames': 290,
#     'drop_percent': 0.2388451443569554},
#    '005': {'total_frames': 402,
#     'good_frames': 260,
#     'drop_percent': 0.35323383084577115}},
#   'left_upper_shoflex': {'016': {'total_frames': 387,
#     'good_frames': 91,
#     'drop_percent': 0.7648578811369509},
#    '008': {'total_frames': 398,
#     'good_frames': 65,
#     'drop_percent': 0.8366834170854272},
#    '001': {'total_frames': 404,
#     'good_frames': 107,
#     'drop_percent': 0.7351485148514851},
#    '004': {'total_frames': 378,
#     'good_frames': 91,
#     'drop_percent': 0.7592592592592593},
#    '013': {'total_frames': 416,
#     'good_frames': 111,
#     'drop_percent': 0.7331730769230769},
#    '015': {'total_frames': 376,
#     'good_frames': 116,
#     'drop_percent': 0.6914893617021277},
#    '017': {'total_frames': 405,
#     'good_frames': 80,
#     'drop_percent': 0.8024691358024691},
#    '007': {'total_frames': 404,
#     'good_frames': 88,
#     'drop_percent': 0.7821782178217822},
#    '009': {'total_frames': 388,
#     'good_frames': 163,
#     'drop_percent': 0.5798969072164949},
#    '005': {'total_frames': 378,
#     'good_frames': 75,
#     'drop_percent': 0.8015873015873016},
#    '011': {'total_frames': 390, 'good_frames': 78, 'drop_percent': 0.8},
#    '002': {'total_frames': 378,
#     'good_frames': 101,
#     'drop_percent': 0.7328042328042328},
#    '014': {'total_frames': 389,
#     'good_frames': 123,
#     'drop_percent': 0.6838046272493573},
#    '012': {'total_frames': 390,
#     'good_frames': 82,
#     'drop_percent': 0.7897435897435897},
#    '003': {'total_frames': 383,
#     'good_frames': 101,
#     'drop_percent': 0.7362924281984334},
#    '006': {'total_frames': 401,
#     'good_frames': 122,
#     'drop_percent': 0.6957605985037406},
#    '018': {'total_frames': 396,
#     'good_frames': 50,
#     'drop_percent': 0.8737373737373737},
#    '020': {'total_frames': 404,
#     'good_frames': 75,
#     'drop_percent': 0.8143564356435643},
#    '010': {'total_frames': 392,
#     'good_frames': 151,
#     'drop_percent': 0.6147959183673469},
#    '019': {'total_frames': 399,
#     'good_frames': 82,
#     'drop_percent': 0.7944862155388471}},
#   'right_upper_shoflex': {'003': {'total_frames': 362,
#     'good_frames': 316,
#     'drop_percent': 0.1270718232044199},
#    '012': {'total_frames': 357,
#     'good_frames': 312,
#     'drop_percent': 0.12605042016806722},
#    '008': {'total_frames': 378,
#     'good_frames': 337,
#     'drop_percent': 0.10846560846560846},
#    '013': {'total_frames': 380,
#     'good_frames': 338,
#     'drop_percent': 0.11052631578947368},
#    '004': {'total_frames': 363,
#     'good_frames': 327,
#     'drop_percent': 0.09917355371900827},
#    '002': {'total_frames': 356,
#     'good_frames': 319,
#     'drop_percent': 0.10393258426966293},
#    '019': {'total_frames': 371,
#     'good_frames': 332,
#     'drop_percent': 0.10512129380053908},
#    '016': {'total_frames': 388,
#     'good_frames': 338,
#     'drop_percent': 0.12886597938144329},
#    '017': {'total_frames': 379,
#     'good_frames': 309,
#     'drop_percent': 0.18469656992084432},
#    '011': {'total_frames': 378,
#     'good_frames': 329,
#     'drop_percent': 0.12962962962962962},
#    '006': {'total_frames': 390,
#     'good_frames': 332,
#     'drop_percent': 0.14871794871794872},
#    '014': {'total_frames': 377,
#     'good_frames': 338,
#     'drop_percent': 0.10344827586206896},
#    '009': {'total_frames': 377,
#     'good_frames': 336,
#     'drop_percent': 0.10875331564986737},
#    '007': {'total_frames': 349,
#     'good_frames': 299,
#     'drop_percent': 0.14326647564469913},
#    '005': {'total_frames': 380,
#     'good_frames': 335,
#     'drop_percent': 0.11842105263157894},
#    '001': {'total_frames': 353,
#     'good_frames': 306,
#     'drop_percent': 0.13314447592067988},
#    '020': {'total_frames': 368,
#     'good_frames': 307,
#     'drop_percent': 0.16576086956521738},
#    '015': {'total_frames': 400, 'good_frames': 369, 'drop_percent': 0.0775},
#    '018': {'total_frames': 359,
#     'good_frames': 309,
#     'drop_percent': 0.1392757660167131},
#    '010': {'total_frames': 353,
#     'good_frames': 271,
#     'drop_percent': 0.23229461756373937}}}}
